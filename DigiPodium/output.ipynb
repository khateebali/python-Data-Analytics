# %% [markdown]
# # 5 variations on print()

# %%
name = "Aexis"
price = 99.00
qty = 10

# %%
print(name, price, qty, price * qty)
# Out:
# Aexis 99.0 10 990.0

# %% [markdown]
# 'Name' purchase 'qty' items for 'price' costing 'total'

# %%
#comma seperated values:
print(name, 'purchases', qty, 'items for', price, 'costing', price*qty)
# Out:
# Aexis purchases 10 items for 99.0 costing 990.0

# %%
# Concattination using + (plus)
print(name + ' purchanses '+ str(qty))
# Out:
# Aexis purchanses 10

# %%
#format specifier using %(module)
print('%s purchases %d items for %f costing %f'
      %(name, qty, price, price * qty))
# Out:
# Aexis purchases 10 items for 99.000000 costing 990.000000

# %%
#format method
print('{} purchases {} items for {} costing {}'.format(name, qty, price, price*qty))
# Out:
# Aexis purchases 10 items for 99.0 costing 990.0

# %%
# f-string
print(f'{name} purchases {qty} items for {price} costing {price*qty}')
# Out:
# Aexis purchases 10 items for 99.0 costing 990.0

# %%
print(f' Name => {name}')
print(f' Item price => ${price}')
print(f' Quantity => {qty}')
print(f' Total price => ${price * qty:.2f}')
# Out:
#  Name => Aexis
#  Item price => $99.0
#  Quantity => 10
#  Total price => $990.00

# %% [markdown]
# ![image.png](attachment:image.png)
